# %% [markdown]
# **Sampling: Approaches and Methods**

# %%
import numpy as np
import pandas as pd

# Creating a simple dataset of 1000 sales
data = {
    "sale_id": np.arange(1, 1001),
    "sale_amount": np.random.randint(50, 500, size=1000),
}
sales_data = pd.DataFrame(data)

# Simple Random Sampling: select 100 random rows
sample_data = sales_data.sample(n=100, random_state=42)

sample_data.head()
# Out:
#      sale_id  sale_amount
# 521      522          161
# 737      738          360
# 740      741          292
# 660      661          104
# 411      412          222
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['sale_id'].plot(kind='hist', bins=20, title='sale_id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['sale_amount'].plot(kind='hist', bins=20, title='sale_amount')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_3.plot(kind='scatter', x='index', y='sale_id', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='sale_id', y='sale_amount', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6['sale_id'].plot(kind='line', figsize=(8, 4), title='sale_id')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7['sale_amount'].plot(kind='line', figsize=(8, 4), title='sale_amount')
# plt.gca().spines[['top', 'right']].set_visible(False)
